# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_excel("wireless_mlpclassifier.xlsx")
data = df.iloc[:, 0:7]
data
# Out:
#     [Low price (낮은 가격)]  [Noise cancelling (노이즈 캔슬링)]  \
# 0                     1                             4
# 1                     3                             5
# 2                     4                             3
# 3                     3                             4
# 4                     4                             5
# ..                  ...                           ...
# 81                    3                             4
# 82                    6                             3
# 83                    5                             6
# 84                    4                             6
# 85                    6                             2
#
#     [Battery time (배터리 시간)]  [Light weight (가벼운 무게)]  [Brand (브랜드)]  \
# 0                         3                        5              6
# 1                         4                        6              2
# 2                         5                        6              2
# 3                         6                        5              1
# 4                         2                        1              6
# ..                      ...                      ...            ...
# 81                        2                        5              6
# 82                        1                        4              5
# 83                        1                        2              4
# 84                        3                        5              1
# 85                        3                        5              1
#
#     [Sound Quality (음질)]  wish device
# 0                      2            1
# 1                      1            2
# 2                      1            2
# 3                      2            2
# 4                      3            1
# ..                   ...          ...
# 81                     1            2
# 82                     2            4
# 83                     3            4
# 84                     2            3
# 85                     4            1
#
# [86 rows x 7 columns]

# %%
scaler = StandardScaler()

# %%
data.iloc[:, 0:6] = scaler.fit_transform(data.iloc[:, 0:6])

# %%
data
# Out:
#     [Low price (낮은 가격)]  [Noise cancelling (노이즈 캔슬링)]  \
# 0             -1.507017                      0.020342
# 1             -0.365136                      0.603490
# 2              0.205804                     -0.562806
# 3             -0.365136                      0.020342
# 4              0.205804                      0.603490
# ..                  ...                           ...
# 81            -0.365136                      0.020342
# 82             1.347685                     -0.562806
# 83             0.776744                      1.186638
# 84             0.205804                      1.186638
# 85             1.347685                     -1.145954
#
#     [Battery time (배터리 시간)]  [Light weight (가벼운 무게)]  [Brand (브랜드)]  \
# 0                  0.008295                 0.527097       1.616713
# 1                  0.721675                 1.270218      -0.653284
# 2                  1.435055                 1.270218      -0.653284
# 3                  2.148435                 0.527097      -1.220783
# 4                 -0.705085                -2.445386       1.616713
# ..                      ...                      ...            ...
# 81                -0.705085                 0.527097       1.616713
# 82                -1.418465                -0.216024       1.049214
# 83                -1.418465                -1.702265       0.481714
# 84                 0.008295                 0.527097      -1.220783
# 85                 0.008295                 0.527097      -1.220783
#
#     [Sound Quality (음질)]  wish device
# 0              -0.305036            1
# 1              -1.014039            2
# 2              -1.014039            2
# 3              -0.305036            2
# 4               0.403967            1
# ..                   ...          ...
# 81             -1.014039            2
# 82             -0.305036            4
# 83              0.403967            4
# 84             -0.305036            3
# 85              1.112969            1
#
# [86 rows x 7 columns]

# %%
training_set, validation_set = train_test_split(data, test_size = 0.2, random_state = 21)

# %%
X_train = training_set.iloc[:,0:6].values
y_train = training_set.iloc[:, -1].values
X_val = validation_set.iloc[:,0:6].values
y_val = validation_set.iloc[:, -1].values

# %%
def accuracy(confusion_matrix):
    diagonal_sum = confusion_matrix.trace()
    sum_of_all_elements = confusion_matrix.sum()
    return diagonal_sum/sum_of_all_elements

# %%
classifier = MLPClassifier(hidden_layer_sizes = (150,100,50),\
                           max_iter= 300, activation = 'relu',\
                          solver = 'adam', random_state = 1)
'''hidden_layer_sizes = (150,100,50),\
                           
    >> 이거 없애면 accuracy = 0.2777777777777778'''
# Out:
# 'hidden_layer_sizes = (150,100,50),                           \n    >> 이거 없애면 accuracy = 0.2777777777777778'

# %%
classifier.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(150, 100, 50), max_iter=300, random_state=1)

# %%
y_pred = classifier.predict(X_val)

# %%
cm = confusion_matrix(y_pred, y_val)

# %%
accuracy(cm)
# Out:
# 0.2222222222222222
